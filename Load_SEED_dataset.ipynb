# %%
# load .mat file
import scipy.io as sio
import numpy as np

mat_contents1 = sio.loadmat('seed/stim_101.mat')
mat_contents2= sio.loadmat('seed/stim_102.mat')
mat_contents3 = sio.loadmat('seed/stim_103.mat')
mat_contents4 = sio.loadmat('seed/stim_104.mat')
mat_contents5 = sio.loadmat('seed/stim_105.mat')
mat_contents6 = sio.loadmat('seed/stim_106.mat')
mat_contents7 = sio.loadmat('seed/stim_107.mat')
mat_contents8 = sio.loadmat('seed/stim_108.mat')
mat_contents9 = sio.loadmat('seed/stim_109.mat')
mat_contents10 = sio.loadmat('seed/stim_110.mat')
# mat_contents11 = sio.loadmat('seed/stim_111.mat')
# mat_contents12 = sio.loadmat('seed/stim_112.mat')
# mat_contents13 = sio.loadmat('seed/stim_113.mat')
mat_contents14 = sio.loadmat('seed/stim_114.mat')
mat_contents15 = sio.loadmat('seed/stim_115.mat')
# mat_contents16 = sio.loadmat('seed/stim_116.mat')


mat_contents1.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'data'])

# %%
data=mat_contents1['data']
data.shape
print(data)
# Out:
# [[[-1.92821026e+01  8.16583633e+00  9.11951065e+00 ...  4.48822975e+01
#     3.57031822e+01 -1.09076500e+01]
#   [-9.29832458e+00  2.95042992e+00  7.18235970e+00 ...  7.35819340e+01
#     2.91764736e+01 -1.46031380e+01]
#   [-2.57790089e+01  3.87430191e-01  5.81145287e+00 ...  5.90980053e+01
#     3.25739384e+01 -1.49011612e+01]
#   ...
#   [-4.17232513e+00 -1.20699406e+01 -2.35438347e+00 ...  1.24275684e+01
#    -1.46031380e+00  2.30073929e+01]
#   [-1.68979168e+01 -1.19209290e+01 -9.20891762e+00 ...  9.03010368e+00
#    -8.94069672e+00  1.15036964e+01]
#   [-1.01923943e+01 -1.06692314e+01 -9.35792923e+00 ...  1.03116035e+01
#    -1.43945217e+01  1.44243240e+01]]
#
#  [[ 1.19209290e+01  2.42590904e+01  9.08970833e+00 ...  4.91738319e+01
#     5.98132610e+01 -1.83880329e+01]
#   [ 2.05338001e+01  1.73151493e+01  6.61611557e+00 ...  3.45706940e+01
#     5.61475754e+01 -1.80602074e+01]
#   [ 1.14142895e+01  1.46627426e+01  5.63263893e+00 ...  4.01139259e+01
# ...
